# %%
# Bakthria ecoli kai streptokokos

ecoli=sc.textFile("Dropbox/διπλωματικη/Ecoli_K_12.txt")
strepto=sc.textFile("Dropbox/διπλωματικη/strepto2.txt")
header1=ecoli.first()
header2=strepto.first()
# O header twra einai string prepei na to ksanakanw rdd gia
# na to afairresw apo to arxeio
header1_2=sc.parallelize([header1])
header2_2=sc.parallelize([header2])
# afairesh header apo to arxeio
ecoli=ecoli.subtract(header1_2)
strepto=strepto.subtract(header2_2)
# enwsh grammwn
ecoli=ecoli.reduce(lambda a,b: a+b)
strepto=strepto.reduce(lambda a,b: a+b)

# %%
ecoli=sc.textFile("Dropbox/διπλωματικη/ecolibig1.txt")
ec2=sc.textFile("Dropbox/διπλωματικη/ecolibig2.txt")
ec3=sc.textFile("Dropbox/διπλωματικη/ecolibig3.txt")
header1=ecoli.first()
header2=ec2.first()
header3=ec3.first()
# O header twra einai string prepei na to ksanakanw rdd gia
# na to afairresw apo to arxeio
header1_2=sc.parallelize([header1])
header2_2=sc.parallelize([header2])
header2_3=sc.parallelize([header3])
# afairesh header apo to arxeio
ecoli=ecoli.subtract(header1_2)
ec2=ec2.subtract(header2_2)
ec3=ec3.subtract(header2_3)
# enwsh grammwn
ecoli=ecoli.reduce(lambda a,b: a+b)
ec2=ec2.reduce(lambda a,b: a+b)
ec3=ec3.reduce(lambda a,b: a+b)

# %%
s="abbabaababaabab"
#
import time
sc.addFile("/home/zak92/LCE_k.py")
import LCE_k
sc.addFile("/home/zak92/LCE.py")
import LCE
sc.addFile("/home/zak92/getBorder.py")
import getBorder
#
#
# Gia elegxo me to s
start_time1=time.time()
LCE.LCE(ec3,0,4864)
end_time1=time.time()
start_time2=time.time()
LCE_k.LCE_k(ec3,0,4864,30)
end_time2=time.time()
start_time3=time.time()
getBorder.getBorder(ec3,30)
end_time3=time.time()
print("LCE--- %s seconds ---" % (end_time1 - start_time1))
print("LCE_k--- %s seconds ---" % (end_time2 - start_time2))
print("getBorder--- %s seconds ---" % (end_time3 - start_time3))
#
#
# 1η εκτελεση apotelesma=423
# Gia elegxo me to ec2 
start_time1=time.time()
LCE.LCE(ecoli,0,434)
end_time1=time.time()
print("LCE--- %s seconds ---" % (end_time1 - start_time1))
start_time2=time.time()
LCE_k.LCE_k(ecoli,0,27,5)
end_time2=time.time()
start_time3=time.time()
getBorder.getBorder(ecoli,1)
end_time3=time.time()
print("LCE_k--- %s seconds ---" % (end_time2 - start_time2))
print("getBorder--- %s seconds ---" % (end_time3 - start_time3))
#

# %%
#2η εκτελεση με το ecoli, naive 15, getborder 38
start_time1=time.time()
LCE.LCE(ecoli,0,264)
end_time1=time.time()
start_time2=time.time()
LCE_k.LCE_k(ecoli,0,264,5)
end_time2=time.time()
start_time3=time.time()
getBorder.getBorder(ecoli,5)
end_time3=time.time()
print("LCE--- %s seconds ---" % (end_time1 - start_time1))
print("LCE_k--- %s seconds ---" % (end_time2 - start_time2))
print("getBorder--- %s seconds ---" % (end_time3 - start_time3))
#

# %%
start_time1=time.time()
LCE.LCE(ecoli2,38,53)
end_time1=time.time()
start_time2=time.time()
LCE_k.LCE_k(ecoli2,0,929,15)
end_time2=time.time()
start_time3=time.time()
getBorder.getBorder(ecoli2,15)
end_time3=time.time()
print("getBorder--- %s seconds ---" % (end_time3 - start_time3))
print("LCE--- %s seconds ---" % (end_time1 - start_time1))
print("LCE_k--- %s seconds ---" % (end_time2 - start_time2))
print("getBorder--- %s seconds ---" % (end_time3 - start_time3))
#

# %%
start_time1=time.time()
LCE.LCE(ecoli2,0,1770)
end_time1=time.time()
start_time2=time.time()
LCE_k.LCE_k(ecoli2,0,1770,30)
end_time2=time.time()
start_time3=time.time()
getBorder.getBorder(ecoli2,30)
end_time3=time.time()
print("getBorder--- %s seconds ---" % (end_time3 - start_time3))
print("LCE--- %s seconds ---" % (end_time1 - start_time1))
print("LCE_k--- %s seconds ---" % (end_time2 - start_time2))
#

# %%
start_time1=time.time()
LCE.LCE(ecoli2,0,1770)
end_time1=time.time()
start_time2=time.time()
LCE_k.LCE_k(ecoli2,0,1770,30)
end_time2=time.time()
start_time3=time.time()
getBorder.getBorder(ecoli2,300)
end_time3=time.time()
print("getBorder--- %s seconds ---" % (end_time3 - start_time3))
print("LCE--- %s seconds ---" % (end_time1 - start_time1))
print("LCE_k--- %s seconds ---" % (end_time2 - start_time2))
#

# %%
#3η εκτελεση με το ecolibig2, naive 23, getborder 181
start_time1=time.time()
LCE.LCE(ec2,16,2199)
end_time1=time.time()
start_time2=time.time()
LCE_k.LCE_k(ec2,0,2089,10)
end_time2=time.time()
start_time3=time.time()
getBorder.getBorder(ec2,10)
end_time3=time.time()
print("LCE--- %s seconds ---" % (end_time1 - start_time1))
print("LCE_k--- %s seconds ---" % (end_time2 - start_time2))
print("getBorder--- %s seconds ---" % (end_time3 - start_time3))
#

# %%
#4η εκτελεση με το ecolibig3, naive 236, getborder 336
start_time1=time.time()
LCE.LCE(ec3,101,8473)
end_time1=time.time()
start_time2=time.time()
LCE_k.LCE_k(ec3,0,8372,7)
end_time2=time.time()
start_time3=time.time()
getBorder.getBorder(ec3,7)
end_time3=time.time()
print("LCE--- %s seconds ---" % (end_time1 - start_time1))
print("LCE_k--- %s seconds ---" % (end_time2 - start_time2))
print("getBorder--- %s seconds ---" % (end_time3 - start_time3))
#

# %%
# Gia elegxo me to 
start_time1=time.time()
LCE.LCE(ec2,0,378) # apotelesma=4
end_time1=time.time()
start_time2=time.time()
LCE_k.LCE_k(ec2,0,378,1)
end_time2=time.time()
start_time3=time.time()
getBorder.getBorder(ec2,378)
end_time3=time.time()
print("LCE--- %s seconds ---" % (end_time1 - start_time1))
print("LCE_k--- %s seconds ---" % (end_time2 - start_time2))
print("getBorder--- %s seconds ---" % (end_time3 - start_time3))
#
