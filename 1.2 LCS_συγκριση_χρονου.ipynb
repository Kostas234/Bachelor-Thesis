# %%
def lcs_d(x,y):
    
    n=len(x)
    m=len(y)
    result=""
    l3n=0
    row=0
    col=0
    L=[[0 for v in range(m+1)]for w in range(n+1)]
    
    for i in range(n+1):
        for j in range(m+1):
            
            if x[i-1]!=y[j-1]:
                L[i][j]=0
            
            elif x[i-1]==y[j-1]:
                L[i][j]=L[i-1][j-1]+1
                if l3n<L[i][j]:
                    l3n=L[i][j]
                    row=i
                    col=j
    
    if l3n==0:
        print "no common substring"
    
    while L[row][col]!=0:
        result=x[row-1]+result
        row-=1
        col-=1
        
    return result

# %%
def lcs_naive(x,y):
    
    length = len(x)
    z = []
    result=""
    for i in range(length):
        for j in range(i,length):
            z.append(x[i:j+1])
    pat=""
    lz=len(z)
    for i in range(lz-1):
        p=KMPSearch(z[i],y)
        if p>=0:
            if len(z[i])>len(pat):
                pat=z[i]
    return pat

   
def KMPSearch(pat, txt):
    M = len(pat)
    N = len(txt)
    lps = [0]*M
    j = 0
    
    computeLPSArray(pat, M, lps)
    i = 0
    while i < N:
        if pat[j] == txt[i]:
            i += 1
            j += 1
 
        if j == M:
            return str(i-j)
            j = lps[j-1]
 
        # mismatch after j matches
        elif i < N and pat[j] != txt[i]:
            if j != 0:
                j = lps[j-1]
            else:
                i += 1
 
def computeLPSArray(pat, M, lps):
    
    len = 0
    lps[0]
    i = 1
    while i < M:
        if pat[i]==pat[len]:
            len += 1
            lps[i] = len
            i += 1
        else:
            if len != 0:
                len = lps[len-1]
            else:
                lps[i] = 0
                i += 1

# %%
def lcs_naive(x,y):
    
    length = len(x)
    z = []
    result=""
    for i in range(length):
        for j in range(i,length):
            z.append(x[i:j+1])
    pat=""
    lz=len(z)
    for i in range(lz-1):
        p=KMPSearch(z[i],y)
        if p>=0:
            if len(z[i])>len(pat):
                pat=z[i]
    return pat

   
def KMPSearch(pat, txt):
    M = len(pat)
    N = len(txt)
    lps = [0]*M
    j = 0
    
    computeLPSArray(pat, M, lps)
    i = 0
    while i < N:
        if pat[j] == txt[i]:
            i += 1
            j += 1
 
        if j == M:
            return str(i-j)
            j = lps[j-1]
 
        # mismatch after j matches
        elif i < N and pat[j] != txt[i]:
            if j != 0:
                j = lps[j-1]
            else:
                i += 1
 
def computeLPSArray(pat, M, lps):
    
    len = 0
    lps[0]
    i = 1
    while i < M:
        if pat[i]==pat[len]:
            len += 1
            lps[i] = len
            i += 1
        else:
            if len != 0:
                len = lps[len-1]
            else:
                lps[i] = 0
                i += 1

# %%
def lcs(x,y):
    
    s=x+"#"+y+"$"
    n=len(s)
    r1=[]
    lcs=""
    
    for i in range(n):
        r1.append(s[i:n])
    r1=sorted(r1) # lexikogragikh taksinomhsh ths listas
    
    for j in range(n-1):
        l=LCP([r1[j],r1[j+1]])
        if len(l)>len(lcs):
               lcs=l
                
    return lcs

def LCP(x):
    
    n=len(x)    
    prefix=""
    m=len(x[0])
    for i in range(n-1):
        m=min(m,len(x[i+1]))
        
    low=0
    high=m
    mid=low+(high-low)/2
    
    for i in range(1,n):
        for j in range(mid):
            if x[i][j]!=x[0][j]:
                prefix=x[0][0:j]
                break
        else:
            prefix=x[0][0:mid]
            
            for w in range(1,n):
                for v in range(mid,high):
                    if x[w][v]!=x[0][v]:
                        prefix=x[0][0:v]
                        break
                else:
                    prefix=x[0][0:high]
                    continue
                break
            continue
        break
        
    return prefix

# %%
import time
from suffix_trees import STree
start_time = time.time()
# Suffix-Tree example.
#st = STree.STree("abcdefghab")
#print(st.find("abc")) # 0
#print(st.find_all("ab")) # [0, 8]

# Generalized Suffix-Tree example.
a = ["...","..."]
st = STree.STree(a)
#print(st.lcs()) # "abc"
b=st.lcs()
end_time = time.time()
print("lcs_stree--- %s seconds ---" % (time.time() - start_time))
start_time = time.time()
c=lcs("...","...")
end_time = time.time()
print("lcs_sarray--- %s seconds ---" % (time.time() - start_time))
#start_time = time.time()
#lcs_naive("...","...")#,100,100)
#end_time = time.time()
#print("lcs_naive--- %s seconds ---" % (time.time() - start_time))
start_time = time.time()
d=lcs_shift("...","...")#,100,100)
end_time = time.time()
print("lcs_shift--- %s seconds ---" % (time.time() - start_time))
start_time = time.time()
e=lcs_d("...","...")#,100,100)
end_time = time.time()
print("lcs_dynamic--- %s seconds ---" % (time.time() - start_time))
# Out:
# lcs_stree--- 0.0508358478546 seconds ---
# lcs_sarray--- 0.0389521121979 seconds ---
# lcs_shift--- 0.733381986618 seconds ---
# lcs_dynamic--- 0.221492052078 seconds ---

# %%
import time
#------->start_time = time.time()
#----->lcs_shift("...","...")#,100,100)
#lcs_shift(dna1,dna2)
#lcs_shift("ACGT","ACG")
#print len(dna1)
#------>print("lcs_shift--- %s seconds ---" % (time.time() - start_time))
start_time = time.time()
#lcs_iterative_with_sequence(dna1,dna2)
lcs_naive("...","...")#,100,100)
#lcs_iterative_with_sequence("ACGT","ACG")
#print("lcs_naive--- %s seconds ---" % (time.time() - start_time))
#------->start_time = time.time()
#------>lcs_dynamic("...","...")#,100,100)
#----->print("lcs_dynamic--- %s seconds ---" % (time.time() - start_time))
#------>start_time = time.time()
#------>st = STree.STree(a)
#------>print("lcs_stree--- %s seconds ---" % (time.time() - start_time))
#start_time = time.time()
#lcs_brute(dna1,dna2)
#lcs_brute("...","...")
#lcs_brute("ACGT","ACG")
#print("lcs_brute--- %s seconds ---" % (time.time() - start_time))
#start_time = time.time()
#lcs_iterative_with_sequence("...","...")#,100,100)
#print("lcs_iterative--- %s seconds ---" % (time.time() - start_time))
start_time = time.time()
lcs_dynamic("...","...")#,100,100)
print("lcs_dyn--- %s seconds ---" % (time.time() - start_time))
